# %% [markdown]
# Q1: What is Estimation Statistics? Explain point estimate and interval estimate.
#
# Estimation statistics involves the process of using sample data to estimate population parameters. There are two main types of estimation:
#
# Point Estimate: A single value calculated from sample data that is used to estimate the population parameter. It provides a "best guess" of the population parameter but does not indicate the uncertainty associated with the estimate.
# Interval Estimate: A range of values calculated from sample data that is used to estimate the population parameter. It provides a range of possible values within which the population parameter is likely to fall, along with a level of confidence associated with the estimate.

# %% [markdown]
# Q2: Write a Python function to estimate the population mean using a sample mean and standard deviation.

# %%
import numpy as np

def estimate_population_mean(sample_mean, sample_std, sample_size):
    """
    Function to estimate the population mean using sample mean, standard deviation, and sample size.
    
    Parameters:
    sample_mean (float): Mean of the sample.
    sample_std (float): Standard deviation of the sample.
    sample_size (int): Size of the sample.
    
    Returns:
    tuple: Lower and upper bounds of the 95% confidence interval.
    """
    margin_of_error = 1.96 * (sample_std / np.sqrt(sample_size))  # 95% confidence level, z-value = 1.96
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error
    return lower_bound, upper_bound

# Example usage:
sample_mean = 500
sample_std = 50
sample_size = 50
confidence_interval = estimate_population_mean(sample_mean, sample_std, sample_size)
print("95% Confidence Interval:", confidence_interval)
# Out:
# 95% Confidence Interval: (486.1407070887437, 513.8592929112564)

# %% [markdown]
# Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.
#
# Hypothesis testing is a statistical method used to make inferences about population parameters based on sample data.
# It involves formulating a hypothesis about the population parameter, collecting sample data, and using statistical tests to determine whether the observed data provides enough evidence to reject or fail to reject the hypothesis.
# Hypothesis testing is used to make decisions and draw conclusions about population parameters, such as means, proportions, and variances, based on sample data.
# The importance of hypothesis testing lies in its ability to provide a systematic framework for making decisions and drawing conclusions in the presence of uncertainty. It allows researchers to evaluate the validity of claims, test hypotheses, and make informed decisions based on empirical evidence.

# %% [markdown]
# Q4: Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.
#
# Null Hypothesis (H0): The average weight of male college students is equal to or less than the average weight of female college students.
# Alternative Hypothesis (H1): The average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# Q5: Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.

# %%
import numpy as np
import scipy.stats

def two_sample_t_test(sample1, sample2, alpha):
    """
    Perform a two-sample t-test for independent samples.
    
    Parameters:
    sample1 (array-like): Sample data for the first population.
    sample2 (array-like): Sample data for the second population.
    alpha (float): Significance level.
    
    Returns:
    tuple: t-statistic and p-value.
    """
    t_statistic, p_value = scipy.stats.ttest_ind(sample1, sample2)
    return t_statistic, p_value

# Example usage:
sample1 = np.random.normal(loc=70, scale=10, size=100)
sample2 = np.random.normal(loc=75, scale=12, size=120)
alpha = 0.05
t_stat, p_val = two_sample_t_test(sample1, sample2, alpha)
print("t-statistic:", t_stat)
print("p-value:", p_val)
# Out:
# t-statistic: -5.3092847729338715
# p-value: 2.705575909367622e-07

# %% [markdown]
# Q6: What is a null and alternative hypothesis? Give some examples.
#
# Null Hypothesis (H0): It is a statement that there is no significant difference or effect. It is typically the default assumption.
# Example: The mean exam scores of two groups are equal.
# Alternative Hypothesis (H1): It is a statement that contradicts the null hypothesis and suggests that there is a significant difference or effect.
# Example: The mean exam scores of two groups are not equal.
# Q7: Write down the steps involved in hypothesis testing.
#
# The steps involved in hypothesis testing are:
#
# Formulate the null and alternative hypotheses.
# Choose the appropriate test statistic and significance level (alpha).
# Collect sample data and calculate the test statistic.
# Determine the critical value or p-value based on the chosen significance level.
# Compare the test statistic with the critical value or p-value.
# Make a decision to either reject or fail to reject the null hypothesis based on the comparison.
# Q8: Define p-value and explain its significance in hypothesis testing.
#
# p-value is the probability of observing a test statistic as extreme as, or more extreme than, the one calculated from the sample data, assuming that the null hypothesis is true.
# It indicates the strength of evidence against the null hypothesis. A small p-value suggests strong evidence against the null hypothesis, leading to its rejection.
# The significance level (alpha) is compared to the p-value to make a decision about rejecting or failing to reject the null hypothesis.
# Q9: Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.

# %% [markdown]
# Q7: Write down the steps involved in hypothesis testing.
#
# The steps involved in hypothesis testing are:
#
# Formulate the null and alternative hypotheses.
# Choose the appropriate test statistic and significance level (alpha).
# Collect sample data and calculate the test statistic.
# Determine the critical value or p-value based on the chosen significance level.
# Compare the test statistic with the critical value or p-value.
# Make a decision to either reject or fail to reject the null hypothesis based on the comparison.
# Q8: Define p-value and explain its significance in hypothesis testing.
#
# p-value is the probability of observing a test statistic as extreme as, or more extreme than, the one calculated from the sample data, assuming that the null hypothesis is true.
# It indicates the strength of evidence against the null hypothesis. A small p-value suggests strong evidence against the null hypothesis, leading to its rejection.
# The significance level (alpha) is compared to the p-value to make a decision about rejecting or failing to reject the null hypothesis.
# Q9: Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.

# %% [markdown]
# Q8: Define p-value and explain its significance in hypothesis testing.
#
# p-value is the probability of observing a test statistic as extreme as, or more extreme than, the one calculated from the sample data, assuming that the null hypothesis is true.
# It indicates the strength of evidence against the null hypothesis. A small p-value suggests strong evidence against the null hypothesis, leading to its rejection.
# The significance level (alpha) is compared to the p-value to make a decision about rejecting or failing to reject the null hypothesis.

# %% [markdown]
# Q9: Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate t-distribution plot
x = np.linspace(-5, 5, 1000)
degrees_of_freedom = 10
t_distribution = scipy.stats.t.pdf(x, df=degrees_of_freedom)
plt.plot(x, t_distribution, label='t-Distribution (df=10)')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.title("Student's t-Distribution (df=10)")
plt.legend()
plt.show()

# %% [markdown]
# Q10: Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.

# %%
import numpy as np
import scipy.stats

def two_sample_t_test(sample1, sample2, alpha):
    """
    Perform a two-sample t-test for independent samples.
    
    Parameters:
    sample1 (array-like): Sample data for the first population.
    sample2 (array-like): Sample data for the second population.
    alpha (float): Significance level.
    
    Returns:
    tuple: t-statistic and p-value.
    """
    t_statistic, p_value = scipy.stats.ttest_ind(sample1, sample2)
    return t_statistic, p_value

# Generate two random samples
sample1 = np.random.normal(loc=50, scale=10, size=100)
sample2 = np.random.normal(loc=50, scale=10, size=100)

# Perform two-sample t-test
alpha = 0.05
t_stat, p_val = two_sample_t_test(sample1, sample2, alpha)
print("t-statistic:", t_stat)
print("p-value:", p_val)
# Out:
# t-statistic: 1.0301141573121217
# p-value: 0.3042130996513654

# %% [markdown]
# Q11: What is Student’s t distribution? When to use the t-Distribution.
#
# Student’s t distribution (or t-Distribution) is a probability distribution that is symmetric and bell-shaped, similar to the normal distribution. It is characterized by its degrees of freedom parameter.
# The t-distribution is used when the sample size is small (< 30) or when the population standard deviation is unknown.

# %% [markdown]
# Q12: What is t-statistic? State the formula for t-statistic.
#
# t-statistic is a measure used in hypothesis testing to determine if the means of two groups are significantly different from each other.
# Formula for t-statistic (for independent samples):
# t = \frac{{\bar{x}_1 - \bar{x}_2}}{{\sqrt{\frac{{s_1^2}}{{n_1}} + \frac{{s_2^2}}{{n_2}}}}
# where:
# �
# ˉ
# 1
# x
# ˉ
#
# 1
# ​
#   and
# �
# ˉ
# 2
# x
# ˉ
#
# 2
# ​
#   are the sample means,
# �
# 1
# s
# 1
# ​
#   and
# �
# 2
# s
# 2
# ​
#   are the sample standard deviations,
# �
# 1
# n
# 1
# ​
#   and
# �
# 2
# n
# 2
# ​
#   are the sample sizes.

# %% [markdown]
# Q13: A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50. Estimate the population mean revenue with a 95% confidence interval.
#
# Given:
#
# Sample mean (
# �
# ˉ
# x
# ˉ
#  ) = $500
# Sample standard deviation (s) = $50
# Sample size (n) = 50
# Confidence level = 95%
# Critical z-value for a 95% confidence level is 1.96
# Margin of Error
# =
# �
# ×
# �
# �
# Margin of Error=Z×
# n
# ​
#
# s
# ​
#
# Lower Bound
# =
# �
# ˉ
# −
# Margin of Error
# Lower Bound=
# x
# ˉ
#  −Margin of Error
# Upper Bound
# =
# �
# ˉ
# +
# Margin of Error
# Upper Bound=
# x
# ˉ
#  +Margin of Error

# %%
import numpy as np

sample_mean = 500
sample_std = 50
sample_size = 50
z_critical = 1.96  # For 95% confidence interval

margin_of_error = z_critical * (sample_std / np.sqrt(sample_size))
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print("95% Confidence Interval for population mean revenue:", (lower_bound, upper_bound))
# Out:
# 95% Confidence Interval for population mean revenue: (486.1407070887437, 513.8592929112564)

# %% [markdown]
# Q1: What is Estimation Statistics? Explain point estimate and interval estimate.
#
# Estimation statistics involves the process of using sample data to estimate population parameters. There are two main types of estimation:
#
# Point Estimate: A single value calculated from sample data that is used to estimate the population parameter. It provides a "best guess" of the population parameter but does not indicate the uncertainty associated with the estimate.
# Interval Estimate: A range of values calculated from sample data that is used to estimate the population parameter. It provides a range of possible values within which the population parameter is likely to fall, along with a level of confidence associated with the estimate.
# Q2: Write a Python function to estimate the population mean using a sample mean and standard deviation.
#
# python
# Copy code
# import numpy as np
#
# def estimate_population_mean(sample_mean, sample_std, sample_size):
#     """
#     Function to estimate the population mean using sample mean, standard deviation, and sample size.
#
#     Parameters:
#     sample_mean (float): Mean of the sample.
#     sample_std (float): Standard deviation of the sample.
#     sample_size (int): Size of the sample.
#
#     Returns:
#     tuple: Lower and upper bounds of the 95% confidence interval.
#     """
#     margin_of_error = 1.96 * (sample_std / np.sqrt(sample_size))  # 95% confidence level, z-value = 1.96
#     lower_bound = sample_mean - margin_of_error
#     upper_bound = sample_mean + margin_of_error
#     return lower_bound, upper_bound
#
# # Example usage:
# sample_mean = 500
# sample_std = 50
# sample_size = 50
# confidence_interval = estimate_population_mean(sample_mean, sample_std, sample_size)
# print("95% Confidence Interval:", confidence_interval)
# Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.
#
# Hypothesis testing is a statistical method used to make inferences about population parameters based on sample data.
# It involves formulating a hypothesis about the population parameter, collecting sample data, and using statistical tests to determine whether the observed data provides enough evidence to reject or fail to reject the hypothesis.
# Hypothesis testing is used to make decisions and draw conclusions about population parameters, such as means, proportions, and variances, based on sample data.
# The importance of hypothesis testing lies in its ability to provide a systematic framework for making decisions and drawing conclusions in the presence of uncertainty. It allows researchers to evaluate the validity of claims, test hypotheses, and make informed decisions based on empirical evidence.
# Q4: Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.
#
# Null Hypothesis (H0): The average weight of male college students is equal to or less than the average weight of female college students.
# Alternative Hypothesis (H1): The average weight of male college students is greater than the average weight of female college students.
# Q5: Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.
#
# python
# Copy code
# import numpy as np
# import scipy.stats
#
# def two_sample_t_test(sample1, sample2, alpha):
#     """
#     Perform a two-sample t-test for independent samples.
#
#     Parameters:
#     sample1 (array-like): Sample data for the first population.
#     sample2 (array-like): Sample data for the second population.
#     alpha (float): Significance level.
#
#     Returns:
#     tuple: t-statistic and p-value.
#     """
#     t_statistic, p_value = scipy.stats.ttest_ind(sample1, sample2)
#     return t_statistic, p_value
#
# # Example usage:
# sample1 = np.random.normal(loc=70, scale=10, size=100)
# sample2 = np.random.normal(loc=75, scale=12, size=120)
# alpha = 0.05
# t_stat, p_val = two_sample_t_test(sample1, sample2, alpha)
# print("t-statistic:", t_stat)
# print("p-value:", p_val)
# Q6: What is a null and alternative hypothesis? Give some examples.
#
# Null Hypothesis (H0): It is a statement that there is no significant difference or effect. It is typically the default assumption.
# Example: The mean exam scores of two groups are equal.
# Alternative Hypothesis (H1): It is a statement that contradicts the null hypothesis and suggests that there is a significant difference or effect.
# Example: The mean exam scores of two groups are not equal.
# Q7: Write down the steps involved in hypothesis testing.
#
# The steps involved in hypothesis testing are:
#
# Formulate the null and alternative hypotheses.
# Choose the appropriate test statistic and significance level (alpha).
# Collect sample data and calculate the test statistic.
# Determine the critical value or p-value based on the chosen significance level.
# Compare the test statistic with the critical value or p-value.
# Make a decision to either reject or fail to reject the null hypothesis based on the comparison.
# Q8: Define p-value and explain its significance in hypothesis testing.
#
# p-value is the probability of observing a test statistic as extreme as, or more extreme than, the one calculated from the sample data, assuming that the null hypothesis is true.
# It indicates the strength of evidence against the null hypothesis. A small p-value suggests strong evidence against the null hypothesis, leading to its rejection.
# The significance level (alpha) is compared to the p-value to make a decision about rejecting or failing to reject the null hypothesis.
# Q9: Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.
#
# python
# Copy code
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Generate t-distribution plot
# x = np.linspace(-5, 5, 1000)
# degrees_of_freedom = 10
# t_distribution = scipy.stats.t.pdf(x, df=degrees_of_freedom)
# plt.plot(x, t_distribution, label='t-Distribution (df=10)')
# plt.xlabel('x')
# plt.ylabel('Probability Density')
# plt.title("Student's t-Distribution (df=10)")
# plt.legend()
# plt.show()
# Q10: Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.
#
# python
# Copy code
# import numpy as np
# import scipy.stats
#
# def two_sample_t_test(sample1, sample2, alpha):
#     """
#     Perform a two-sample t-test for independent samples.
#
#     Parameters:
#     sample1 (array-like): Sample data for the first population.
#     sample2 (array-like): Sample data for the second population.
#     alpha (float): Significance level.
#
#     Returns:
#     tuple: t-statistic and p-value.
#     """
#     t_statistic, p_value = scipy.stats.ttest_ind(sample1, sample2)
#     return t_statistic, p_value
#
# # Generate two random samples
# sample1 = np.random.normal(loc=50, scale=10, size=100)
# sample2 = np.random.normal(loc=50, scale=10, size=100)
#
# # Perform two-sample t-test
# alpha = 0.05
# t_stat, p_val = two_sample_t_test(sample1, sample2, alpha)
# print("t-statistic:", t_stat)
# print("p-value:", p_val)
# Q11: What is Student’s t distribution? When to use the t-Distribution.
#
# Student’s t distribution (or t-Distribution) is a probability distribution that is symmetric and bell-shaped, similar to the normal distribution. It is characterized by its degrees of freedom parameter.
# The t-distribution is used when the sample size is small (< 30) or when the population standard deviation is unknown.
# Q12: What is t-statistic? State the formula for t-statistic.
#
# t-statistic is a measure used in hypothesis testing to determine if the means of two groups are significantly different from each other.
# Formula for t-statistic (for independent samples):
# t = \frac{{\bar{x}_1 - \bar{x}_2}}{{\sqrt{\frac{{s_1^2}}{{n_1}} + \frac{{s_2^2}}{{n_2}}}}
# where:
# �
# ˉ
# 1
# x
# ˉ
#
# 1
# ​
#   and
# �
# ˉ
# 2
# x
# ˉ
#
# 2
# ​
#   are the sample means,
# �
# 1
# s
# 1
# ​
#   and
# �
# 2
# s
# 2
# ​
#   are the sample standard deviations,
# �
# 1
# n
# 1
# ​
#   and
# �
# 2
# n
# 2
# ​
#   are the sample sizes.
# Q13: A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50. Estimate the population mean revenue with a 95% confidence interval.
#
# Given:
#
# Sample mean (
# �
# ˉ
# x
# ˉ
#  ) = $500
# Sample standard deviation (s) = $50
# Sample size (n) = 50
# Confidence level = 95%
# Critical z-value for a 95% confidence level is 1.96
# Margin of Error
# =
# �
# ×
# �
# �
# Margin of Error=Z×
# n
# ​
#
# s
# ​
#
# Lower Bound
# =
# �
# ˉ
# −
# Margin of Error
# Lower Bound=
# x
# ˉ
#  −Margin of Error
# Upper Bound
# =
# �
# ˉ
# +
# Margin of Error
# Upper Bound=
# x
# ˉ
#  +Margin of Error
#
# python
# Copy code
# import numpy as np
#
# sample_mean = 500
# sample_std = 50
# sample_size = 50
# z_critical = 1.96  # For 95% confidence interval
#
# margin_of_error = z_critical * (sample_std / np.sqrt(sample_size))
# lower_bound = sample_mean - margin_of_error
# upper_bound = sample_mean + margin_of_error
#
# print("95% Confidence Interval for population mean revenue:", (lower_bound, upper_bound))
# Q14: A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.
#
# Given:
#
# Null Hypothesis (H0): The mean decrease in blood pressure is 10 mmHg (
# �
# =
# 10
# μ=10)
# Alternative Hypothesis (H1): The mean decrease in blood pressure is less than 10 mmHg (
# �
# <
# 10
# μ<10)
# Sample mean (
# �
# ˉ
# x
# ˉ
#  ) = 8 mmHg
# Sample standard deviation (s) = 3 mmHg
# Sample size (n) = 100
# Significance level (alpha) = 0.05
# Perform one-sample t-test:

# %%
import numpy as np
import scipy.stats

sample_mean = 8
population_mean = 10
sample_std = 3
sample_size = 100
alpha = 0.05

t_statistic = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))
p_value = scipy.stats.t.cdf(t_statistic, df=sample_size-1)

print("t-statistic:", t_statistic)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject Null Hypothesis: There is sufficient evidence to conclude that the new drug decreases blood pressure.")
else:
    print("Fail to Reject Null Hypothesis: There is not enough evidence to conclude that the new drug decreases blood pressure.")
# Out:
# t-statistic: -6.666666666666667
# p-value: 7.506144504985108e-10
# Reject Null Hypothesis: There is sufficient evidence to conclude that the new drug decreases blood pressure.

# %% [markdown]
# Q14: A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %%
import numpy as np
import scipy.stats

sample_mean = 8
population_mean = 10
sample_std = 3
sample_size = 100
alpha = 0.05

t_statistic = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))
p_value = scipy.stats.t.cdf(t_statistic, df=sample_size-1)

print("t-statistic:", t_statistic)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject Null Hypothesis: There is sufficient evidence to conclude that the new drug decreases blood pressure.")
else:
    print("Fail to Reject Null Hypothesis: There is not enough evidence to conclude that the new drug decreases blood pressure.")
# Out:
# t-statistic: -6.666666666666667
# p-value: 7.506144504985108e-10
# Reject Null Hypothesis: There is sufficient evidence to conclude that the new drug decreases blood pressure.

# %% [markdown]
# Q15: An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.

# %%
import numpy as np
import scipy.stats

sample_mean = 4.8
population_mean = 5
sample_std = 0.5
sample_size = 25
alpha = 0.01

t_statistic = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))
p_value = scipy.stats.t.cdf(t_statistic, df=sample_size-1)

print("t-statistic:", t_statistic)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject Null Hypothesis: The true mean weight of the products is less than 5 pounds.")
else:
    print("Fail to Reject Null Hypothesis: There is not enough evidence to conclude that the true mean weight is less than 5 pounds.")
# Out:
# t-statistic: -2.0000000000000018
# p-value: 0.02846992496829572
# Fail to Reject Null Hypothesis: There is not enough evidence to conclude that the true mean weight is less than 5 pounds.

# %% [markdown]
# Q16: Two groups of students are given different study materials to prepare for a test. The first group (n1 = 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two groups are equal with a significance level of 0.01.

# %%
import numpy as np
import scipy.stats

# Sample 1
n1 = 30
sample_mean1 = 80
sample_std1 = 10

# Sample 2
n2 = 40
sample_mean2 = 75
sample_std2 = 8

alpha = 0.01

t_statistic, p_value = scipy.stats.ttest_ind_from_stats(sample_mean1, sample_std1, n1, sample_mean2, sample_std2, n2)

print("t-statistic:", t_statistic)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject Null Hypothesis: The population means for the two groups are not equal.")
else:
    print("Fail to Reject Null Hypothesis: There is not enough evidence to conclude that the population means are different.")
# Out:
# t-statistic: 2.323967729699292
# p-value: 0.02312301341372599
# Fail to Reject Null Hypothesis: There is not enough evidence to conclude that the population means are different.

# %% [markdown]
# Q17: A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %%
import numpy as np

sample_mean = 4
sample_std = 1.5
sample_size = 50
z_critical = 2.576  # For 99% confidence interval

margin_of_error = z_critical * (sample_std / np.sqrt(sample_size))
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print("99% Confidence Interval for population mean:", (lower_bound, upper_bound))
# Out:
# 99% Confidence Interval for population mean: (3.453547879499036, 4.546452120500964)
